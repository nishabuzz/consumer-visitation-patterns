# %% [markdown]
# # QUESTION-1.Plot new users acquired every month on a bar chart (New user in a month = a customer who has placed a request for the first time ever)

# %% [markdown]
# import pandas as pd
# import numpy as np
# df=pd.read_excel("test.xlsx")
# df.head(10)

# %%
import pandas as pd
import numpy as np
df=pd.read_excel("test.xlsx")
df.head()
# Out:
#   Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested Source  \
# 0          BBCHH           1      2018-05-20                2018-05-21      D
# 1          CHWFD           1      2018-09-23                2018-09-23      C
# 2          DYDMF           2      2018-11-10                2018-11-13      C
# 3          EZYSA           3      2018-04-12                2018-04-16      B
# 4          HWAKX           3      2018-08-05                2018-08-06      B
#
#    Slot of Booking (Hour of the Day)
# 0                                 14
# 1                                  8
# 2                                 11
# 3                                  8
# 4                                 11

# %%
df = df.drop_duplicates(subset=['Profile ID'],keep='first')
df.head()
# Out:
#   Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested Source  \
# 0          BBCHH           1      2018-05-20                2018-05-21      D
# 2          DYDMF           2      2018-11-10                2018-11-13      C
# 3          EZYSA           3      2018-04-12                2018-04-16      B
# 5          YRKFO           4      2018-03-02                2018-03-05      A
# 6          JSFWY           5      2018-01-06                2018-01-07      C
#
#    Slot of Booking (Hour of the Day)
# 0                                 14
# 2                                 11
# 3                                  8
# 5                                 13
# 6                                 14

# %%
df['year_month'] = pd.to_datetime(df['Date_of_Service_Requested']).dt.to_period('M')
df.head()
# Out:
#   Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested Source  \
# 0          BBCHH           1      2018-05-20                2018-05-21      D
# 2          DYDMF           2      2018-11-10                2018-11-13      C
# 3          EZYSA           3      2018-04-12                2018-04-16      B
# 5          YRKFO           4      2018-03-02                2018-03-05      A
# 6          JSFWY           5      2018-01-06                2018-01-07      C
#
#    Slot of Booking (Hour of the Day) year_month
# 0                                 14    2018-05
# 2                                 11    2018-11
# 3                                  8    2018-04
# 5                                 13    2018-03
# 6                                 14    2018-01

# %%
df[['Profile ID','Date_of_Service_Requested','year_month']]
# Out:
#        Profile ID Date_of_Service_Requested year_month
# 0               1                2018-05-21    2018-05
# 2               2                2018-11-13    2018-11
# 3               3                2018-04-16    2018-04
# 5               4                2018-03-05    2018-03
# 6               5                2018-01-07    2018-01
# 7               6                2018-07-21    2018-07
# 8               7                2017-12-12    2017-12
# 9               8                2018-11-29    2018-11
# 11              9                2018-03-09    2018-03
# 12             10                2018-10-30    2018-10
# 13             11                2018-10-03    2018-10
# 14             12                2018-02-23    2018-02
# 15             13                2018-03-25    2018-03
# 16             14                2018-05-01    2018-05
# 22             15                2018-08-23    2018-08
# 23             16                2018-09-10    2018-09
# ...

# %%
df['year_month'].value_counts()
# Out:
# 2017-12    2236
# 2018-01    1920
# 2018-02    1571
# 2018-03    1497
# 2018-04    1367
# 2018-05    1284
# 2018-06    1275
# 2018-07    1175
# 2018-08    1151
# 2018-10    1100
# 2018-09    1034
# 2018-11    1014
# 2018-12      87
# Freq: M, Name: year_month, dtype: int64

# %%
ax = df['year_month'].value_counts().plot(kind='bar',
                                    figsize=(15,10),
                                    title="NEW USER PER MONTH")
ax.set_xlabel("year_month")
ax.set_ylabel("NEW USER")
# Out:
# Text(0, 0.5, 'NEW USER')

# %% [markdown]
# ##2.30-Day repeat rate is defined as percentage of new users who have placed a 2nd order within 30 days of placing their first order.
# What is the 30-day repeat rate of users acquired in December 2017?

# %%
import pandas as pd
import numpy as np
df=pd.read_excel("test.xlsx")
df
# Out:
#       Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested  \
# 0              BBCHH           1      2018-05-20                2018-05-21
# 1              CHWFD           1      2018-09-23                2018-09-23
# 2              DYDMF           2      2018-11-10                2018-11-13
# 3              EZYSA           3      2018-04-12                2018-04-16
# 4              HWAKX           3      2018-08-05                2018-08-06
# 5              YRKFO           4      2018-03-02                2018-03-05
# 6              JSFWY           5      2018-01-06                2018-01-07
# 7              GTLXK           6      2018-07-18                2018-07-21
# 8              BGNZX           7      2017-12-07                2017-12-12
# 9              TDVFU           8      2018-11-29                2018-11-29
# 10             LRPOS           8      2018-11-30                2018-11-30
# ...

# %%
import pandas as pd
import numpy as np

# %%
df['Date_of_Booking'] = pd.to_datetime(df['Date_of_Booking'])

# %%
start_date = '2017-12-01'
end_date = '2017-12-31'

# %%
mask = (df['Date_of_Booking'] > start_date) & (df['Date_of_Booking'] <= end_date)

# %%
df = df.loc[mask]
df
# Out:
#       Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested  \
# 8              BGNZX           7      2017-12-07                2017-12-12
# 25             IXAJB          18      2017-12-30                2018-01-03
# 35             RCZNH          25      2017-12-30                2018-01-03
# 67             DSGKZ          44      2017-12-10                2017-12-14
# 70             KZJGH          47      2017-12-19                2017-12-19
# 91             JMFUM          50      2017-12-04                2017-12-08
# 95             OBGFS          52      2017-12-10                2017-12-15
# 118            PVBZX          57      2017-12-16                2017-12-21
# 141            AKNPS          73      2017-12-10                2017-12-12
# 148            KRDXV          79      2017-12-27                2017-12-29
# 149            XIAKH          79      2017-12-29                2018-01-01
# ...

# %%
df.head(100)
# Out:
#      Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested  \
# 8             BGNZX           7      2017-12-07                2017-12-12
# 25            IXAJB          18      2017-12-30                2018-01-03
# 35            RCZNH          25      2017-12-30                2018-01-03
# 67            DSGKZ          44      2017-12-10                2017-12-14
# 70            KZJGH          47      2017-12-19                2017-12-19
# 91            JMFUM          50      2017-12-04                2017-12-08
# 95            OBGFS          52      2017-12-10                2017-12-15
# 118           PVBZX          57      2017-12-16                2017-12-21
# 141           AKNPS          73      2017-12-10                2017-12-12
# 148           KRDXV          79      2017-12-27                2017-12-29
# 149           XIAKH          79      2017-12-29                2018-01-01
# 160           NUIIF          87      2017-12-29                2018-01-03
# ...

# %%
df.duplicated()
# Out:
# 8        False
# 25       False
# 35       False
# 67       False
# 70       False
# 91       False
# 95       False
# 118      False
# 141      False
# 148      False
# 149      False
# 160      False
# 163      False
# 183      False
# 191      False
# 204      False
# 219      False
# 246      False
# 248      False
# 250      False
# 251      False
# 261      False
# 278      False
# 297      False
# 307      False
# 318      False
# 320      False
# 321      False
# 335      False
# 338      False
#          ...
# 30580    False
# 30586    False
# 30595    False
# 30596    False
# 30597    False
# 30613    False
# 30647    False
# 30654    False
# 30661    False
# 30662    False
# 30663    False
# 30680    False
# 30681    False
# 30687    False
# 30690    False
# 30691    False
# 30697    False
# 30714    False
# 30722    False
# 30723    False
# 30738    False
# 30739    False
# 30740    False
# 30780    False
# 30781    False
# 30824    False
# 30850    False
# ...

# %%
df.shape
# Out:
# (2573, 6)

# %%
df.head()
# Out:
#    Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested  \
# 8           BGNZX           7      2017-12-07                2017-12-12
# 25          IXAJB          18      2017-12-30                2018-01-03
# 35          RCZNH          25      2017-12-30                2018-01-03
# 67          DSGKZ          44      2017-12-10                2017-12-14
# 70          KZJGH          47      2017-12-19                2017-12-19
#
#    Source  Slot of Booking (Hour of the Day)
# 8       D                                 16
# 25      C                                 14
# 35      A                                 16
# 67      B                                 11
# 70      B                                 14

# %%
df.set_index('Transaction_ID',inplace=True)

# %%
df.head()
# Out:
#                 Profile ID Date_of_Booking Date_of_Service_Requested Source  \
# Transaction_ID
# BGNZX                    7      2017-12-07                2017-12-12      D
# IXAJB                   18      2017-12-30                2018-01-03      C
# RCZNH                   25      2017-12-30                2018-01-03      A
# DSGKZ                   44      2017-12-10                2017-12-14      B
# KZJGH                   47      2017-12-19                2017-12-19      B
#
#                 Slot of Booking (Hour of the Day)
# Transaction_ID
# BGNZX                                          16
# IXAJB                                          14
# RCZNH                                          16
# DSGKZ                                          11
# KZJGH                                          14

# %%
df.rename(columns={'Profile ID':'Profile_ID',},inplace=True)
print(df.columns)
df.head()
# Out:
# Index(['Profile_ID', 'Date_of_Booking', 'Date_of_Service_Requested', 'Source',
#        'Slot of Booking (Hour of the Day)'],
#       dtype='object')
# C:\Users\sumit\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#                 Profile_ID Date_of_Booking Date_of_Service_Requested Source  \
# Transaction_ID
# BGNZX                    7      2017-12-07                2017-12-12      D
# IXAJB                   18      2017-12-30                2018-01-03      C
# RCZNH                   25      2017-12-30                2018-01-03      A
# DSGKZ                   44      2017-12-10                2017-12-14      B
# KZJGH                   47      2017-12-19                2017-12-19      B
#
# ...

# %%
df.Profile_ID.duplicated()
# Out:
# Transaction_ID
# BGNZX    False
# IXAJB    False
# RCZNH    False
# DSGKZ    False
# KZJGH    False
# JMFUM    False
# OBGFS    False
# PVBZX    False
# AKNPS    False
# KRDXV    False
# XIAKH     True
# NUIIF    False
# SUZIG    False
# BZYSP    False
# SOERW    False
# MXMKR    False
# BEZOK    False
# OUJIU    False
# DSSUP    False
# EEQDR    False
# KLEOV     True
# NETEW    False
# PWCKN    False
# CIRRT    False
# LNQLP    False
# UDBJB    False
# HPZYO    False
# EVYIE    False
# VJYHV    False
# NFOOJ    False
#          ...
# ODYBZ    False
# RPUFQ    False
# VNCYQ    False
# WVVDC     True
# EKATK     True
# EAEJI    False
# VBEXP    False
# ACFBI    False
# FHMHK    False
# CKKID     True
# SEGSB     True
# RCYJI    False
# JXOJV     True
# DDVGX    False
# RWJKM    False
# NJIRJ     True
# WCXWZ    False
# YWIOH    False
# EETCD    False
# HUAMC     True
# WIBIB    False
# VVRRS     True
# YHHIO     True
# SVUQY    False
# QXDKO     True
# QXGPL    False
# ...

# %%
df.Profile_ID.duplicated().sum()
# Out:
# 303

# %% [markdown]
# ## Total  Customer=2572
# ## Return custmer=303
# ## Return Rate(%)=(303/2572)*100=11.78%

# %% [markdown]
# # QUESTION-3 What is the 90-day repeat rate of users acquired in Jan,Feb,March 2018?

# %%
import pandas as pd
import numpy as np
df1=pd.read_excel("test.xlsx")
df1
# Out:
#       Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested  \
# 0              BBCHH           1      2018-05-20                2018-05-21
# 1              CHWFD           1      2018-09-23                2018-09-23
# 2              DYDMF           2      2018-11-10                2018-11-13
# 3              EZYSA           3      2018-04-12                2018-04-16
# 4              HWAKX           3      2018-08-05                2018-08-06
# 5              YRKFO           4      2018-03-02                2018-03-05
# 6              JSFWY           5      2018-01-06                2018-01-07
# 7              GTLXK           6      2018-07-18                2018-07-21
# 8              BGNZX           7      2017-12-07                2017-12-12
# 9              TDVFU           8      2018-11-29                2018-11-29
# 10             LRPOS           8      2018-11-30                2018-11-30
# ...

# %%
import pandas as pd
import numpy as np
df1['Date_of_Booking'] = pd.to_datetime(df1['Date_of_Booking'])
start_date = '2018-01-01'
end_date = '2018-03-31'
mask = (df1['Date_of_Booking'] > start_date) & (df1['Date_of_Booking'] <= end_date)
df1 = df1.loc[mask]
df1
# Out:
#       Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested  \
# 5              YRKFO           4      2018-03-02                2018-03-05
# 6              JSFWY           5      2018-01-06                2018-01-07
# 11             HFTDN           9      2018-03-08                2018-03-09
# 14             UWZXB          12      2018-02-20                2018-02-23
# 15             SQLIO          13      2018-03-21                2018-03-25
# 27             MKPZY          19      2018-02-06                2018-02-08
# 30             PWHVT          22      2018-01-29                2018-02-02
# 42             PXRZK          29      2018-02-22                2018-02-26
# 45             GRUDK          32      2018-02-24                2018-03-01
# 48             ZVXZZ          33      2018-03-06                2018-03-06
# 50             DKOCM          34      2018-02-28                2018-03-05
# ...

# %%
df1.set_index('Transaction_ID',inplace=True)
df1.head()
# Out:
#                 Profile ID Date_of_Booking Date_of_Service_Requested Source  \
# Transaction_ID
# YRKFO                    4      2018-03-02                2018-03-05      A
# JSFWY                    5      2018-01-06                2018-01-07      C
# HFTDN                    9      2018-03-08                2018-03-09      B
# UWZXB                   12      2018-02-20                2018-02-23      B
# SQLIO                   13      2018-03-21                2018-03-25      A
#
#                 Slot of Booking (Hour of the Day)
# Transaction_ID
# YRKFO                                          13
# JSFWY                                          14
# HFTDN                                          14
# UWZXB                                          11
# SQLIO                                          15

# %%
df1.rename(columns={'Profile ID':'Profile_ID',},inplace=True)
print(df1.columns)
df1.head(10)
# Out:
# Index(['Profile_ID', 'Date_of_Booking', 'Date_of_Service_Requested', 'Source',
#        'Slot of Booking (Hour of the Day)'],
#       dtype='object')
#                 Profile_ID Date_of_Booking Date_of_Service_Requested Source  \
# Transaction_ID
# YRKFO                    4      2018-03-02                2018-03-05      A
# JSFWY                    5      2018-01-06                2018-01-07      C
# HFTDN                    9      2018-03-08                2018-03-09      B
# UWZXB                   12      2018-02-20                2018-02-23      B
# SQLIO                   13      2018-03-21                2018-03-25      A
# MKPZY                   19      2018-02-06                2018-02-08      C
# PWHVT                   22      2018-01-29                2018-02-02      A
# PXRZK                   29      2018-02-22                2018-02-26      B
# GRUDK                   32      2018-02-24                2018-03-01      D
# ...

# %%
df1.Profile_ID.duplicated().sum()
# Out:
# 1947

# %% [markdown]
# ## JAN2018 Returning rate=(1903/7500)*100=25.73%

# %%
import pandas as pd
import numpy as np
df2=pd.read_excel("test.xlsx")
df2['Date_of_Booking'] = pd.to_datetime(df2['Date_of_Booking'])
start_date = '2018-02-01'
end_date = '2018-04-30'
mask = (df2['Date_of_Booking'] > start_date) & (df2['Date_of_Booking'] <= end_date)
df2 = df2.loc[mask]
df2.head()
# Out:
#    Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested  \
# 3           EZYSA           3      2018-04-12                2018-04-16
# 5           YRKFO           4      2018-03-02                2018-03-05
# 11          HFTDN           9      2018-03-08                2018-03-09
# 14          UWZXB          12      2018-02-20                2018-02-23
# 15          SQLIO          13      2018-03-21                2018-03-25
#
#    Source  Slot of Booking (Hour of the Day)
# 3       B                                  8
# 5       A                                 13
# 11      B                                 14
# 14      B                                 11
# 15      A                                 15

# %%
df2.rename(columns={'Profile ID':'Profile_ID',},inplace=True)
print(df2.columns)
# Out:
# Index(['Transaction_ID', 'Profile_ID', 'Date_of_Booking',
#        'Date_of_Service_Requested', 'Source',
#        'Slot of Booking (Hour of the Day)'],
#       dtype='object')
# 1947

# %%
df2.Profile_ID.duplicated().sum()
# Out:
# 1842

# %% [markdown]
# ## Feb 7414-1842=24.84%

# %%
import pandas as pd
import numpy as np
df3=pd.read_excel("test.xlsx")
df3['Date_of_Booking'] = pd.to_datetime(df3['Date_of_Booking'])
start_date = '2018-03-01'
end_date = '2018-06-30'
mask = (df3['Date_of_Booking'] > start_date) & (df3['Date_of_Booking'] <= end_date)
df3 = df3.loc[mask]
df3
# Out:
#       Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested  \
# 0              BBCHH           1      2018-05-20                2018-05-21
# 3              EZYSA           3      2018-04-12                2018-04-16
# 5              YRKFO           4      2018-03-02                2018-03-05
# 11             HFTDN           9      2018-03-08                2018-03-09
# 15             SQLIO          13      2018-03-21                2018-03-25
# 16             OCGQD          14      2018-04-30                2018-05-01
# 17             PRFVG          14      2018-06-07                2018-06-07
# 18             SFYTJ          14      2018-06-21                2018-06-23
# 19             SBKYD          14      2018-06-24                2018-06-29
# 20             CJIHM          14      2018-06-29                2018-07-01
# 24             MCQPG          17      2018-04-04                2018-04-07
# ...

# %%
df3.rename(columns={'Profile ID':'Profile_ID',},inplace=True)
print(df3.columns)
# Out:
# Index(['Transaction_ID', 'Profile_ID', 'Date_of_Booking',
#        'Date_of_Service_Requested', 'Source',
#        'Slot of Booking (Hour of the Day)'],
#       dtype='object')

# %%
df1.Profile_ID.duplicated().sum()
# Out:
# 1947

# %% [markdown]
# ##1947/10072=19.3%

# %%
data= np.array([[ 25.73,24.84,19.3]])
print(data)
# Out:
# [[25.73 24.84 19.3 ]]

# %%
from pandas import DataFrame

user= {'MONTH': ['JAN','FEB','MARCH'],
        'RETURN_RATE': [25.73,24.84,19.3]
        }

df5 = DataFrame(user,columns= ['MONTH', 'RETURN_RATE'])

print (df5)
# Out:
#    MONTH  RETURN_RATE
# 0    JAN        25.73
# 1    FEB        24.84
# 2  MARCH        19.30

# %%
df5.set_index('MONTH',inplace=True)

# %%
ax = df5.plot(kind='bar',figsize=(10,5),title="USER RETURN RATE IN % MONTH IN 90 DAYS INTERVAL")
ax.set_xlabel("MONTH")
ax.set_ylabel("RETURN_RATE(IN %)")
# Out:
# Text(0, 0.5, 'RETURN_RATE(IN %)')

# %% [markdown]
# ##Use logistic regression to predict the 90-day repeat of users acquired in November 2018.
# Hint: Use Source, Slot of Booking, Gap between date of Booking and date of service requested as predictor variables

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math
df=pd.read_excel("test.xlsx")
df.head()
# Out:
#   Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested Source  \
# 0          BBCHH           1      2018-05-20                2018-05-21      D
# 1          CHWFD           1      2018-09-23                2018-09-23      C
# 2          DYDMF           2      2018-11-10                2018-11-13      C
# 3          EZYSA           3      2018-04-12                2018-04-16      B
# 4          HWAKX           3      2018-08-05                2018-08-06      B
#
#    Slot of Booking (Hour of the Day)
# 0                                 14
# 1                                  8
# 2                                 11
# 3                                  8
# 4                                 11

# %%
sns.countplot(x="Source",data=df)

# %%
df['Difference'] = df['Date_of_Service_Requested'].sub(df['Date_of_Booking'], axis=0)
df.head()
# Out:
#   Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested Source  \
# 0          BBCHH           1      2018-05-20                2018-05-21      D
# 1          CHWFD           1      2018-09-23                2018-09-23      C
# 2          DYDMF           2      2018-11-10                2018-11-13      C
# 3          EZYSA           3      2018-04-12                2018-04-16      B
# 4          HWAKX           3      2018-08-05                2018-08-06      B
#
#    Slot of Booking (Hour of the Day) Difference
# 0                                 14     1 days
# 1                                  8     0 days
# 2                                 11     3 days
# 3                                  8     4 days
# 4                                 11     1 days

# %%
sns.countplot(x="Source",hue="Difference",data=df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30940 entries, 0 to 30939
# Data columns (total 7 columns):
# Transaction_ID                       30940 non-null object
# Profile ID                           30940 non-null int64
# Date_of_Booking                      30940 non-null datetime64[ns]
# Date_of_Service_Requested            30940 non-null datetime64[ns]
# Source                               30940 non-null object
# Slot of Booking (Hour of the Day)    30940 non-null int64
# Difference                           30940 non-null timedelta64[ns]
# dtypes: datetime64[ns](2), int64(2), object(2), timedelta64[ns](1)
# memory usage: 1.7+ MB

# %%
df.isnull().sum()
# Out:
# Transaction_ID                       0
# Profile ID                           0
# Date_of_Booking                      0
# Date_of_Service_Requested            0
# Source                               0
# Slot of Booking (Hour of the Day)    0
# Difference                           0
# dtype: int64

# %%
sns.boxplot(x="Source",y="Slot of Booking (Hour of the Day)",data=df)

# %% [markdown]
# # train data_set

# %%
df.head()
# Out:
#   Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested Source  \
# 0          BBCHH           1      2018-05-20                2018-05-21      D
# 1          CHWFD           1      2018-09-23                2018-09-23      C
# 2          DYDMF           2      2018-11-10                2018-11-13      C
# 3          EZYSA           3      2018-04-12                2018-04-16      B
# 4          HWAKX           3      2018-08-05                2018-08-06      B
#
#    Slot of Booking (Hour of the Day)
# 0                                 14
# 1                                  8
# 2                                 11
# 3                                  8
# 4                                 11

# %%
df.head()
# Out:
#    Profile ID Date_of_Booking Date_of_Service_Requested Source  \
# 0           1      2018-05-20                2018-05-21      D
# 1           1      2018-09-23                2018-09-23      C
# 2           2      2018-11-10                2018-11-13      C
# 3           3      2018-04-12                2018-04-16      B
# 4           3      2018-08-05                2018-08-06      B
#
#   Difference_between request & booking
# 0                               1 days
# 1                               0 days
# 2                               3 days
# 3                               4 days
# 4                               1 days

# %%
df['Difference_between request & booking'] = df['Date_of_Service_Requested'].sub(df['Date_of_Booking'], axis=0)
df.head()
# Out:
#    Profile ID Date_of_Booking Date_of_Service_Requested Source  \
# 0           1      2018-05-20                2018-05-21      D
# 1           1      2018-09-23                2018-09-23      C
# 2           2      2018-11-10                2018-11-13      C
# 3           3      2018-04-12                2018-04-16      B
# 4           3      2018-08-05                2018-08-06      B
#
#   Difference_between request & booking
# 0                               1 days
# 1                               0 days
# 2                               3 days
# 3                               4 days
# 4                               1 days

# %%
x=df.drop("Difference_between request & booking",axis=1) 
y=df["Difference_between request & booking"]

# %%
from sklearn.model_selection import train_test_split

# %%
 x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.33, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel= LogisticRegression()

# %% [markdown]
# # i tried to solve question no #4  but not complete .......

# %% [markdown]
# # #question no #5 Plot the distribution of users by frequency of their 90-day repeat (Number of times user repeated within first 90 days)

# %%
import pandas as pd
import numpy as np
df=pd.read_excel("test.xlsx")
df.head()
# Out:
#   Transaction_ID  Profile ID Date_of_Booking Date_of_Service_Requested Source  \
# 0          BBCHH           1      2018-05-20                2018-05-21      D
# 1          CHWFD           1      2018-09-23                2018-09-23      C
# 2          DYDMF           2      2018-11-10                2018-11-13      C
# 3          EZYSA           3      2018-04-12                2018-04-16      B
# 4          HWAKX           3      2018-08-05                2018-08-06      B
#
#    Slot of Booking (Hour of the Day)
# 0                                 14
# 1                                  8
# 2                                 11
# 3                                  8
# 4                                 11

# %%
df=df[df.duplicated(['Profile ID'], keep=False)]

# %%
df.set_index('Profile ID',inplace=True)
df.head()
# Out:
#            Transaction_ID Date_of_Booking Date_of_Service_Requested Source  \
# Profile ID
# 1                   BBCHH      2018-05-20                2018-05-21      D
# 1                   CHWFD      2018-09-23                2018-09-23      C
# 3                   EZYSA      2018-04-12                2018-04-16      B
# 3                   HWAKX      2018-08-05                2018-08-06      B
# 8                   TDVFU      2018-11-29                2018-11-29      C
#
#             Slot of Booking (Hour of the Day)
# Profile ID
# 1                                          14
# 1                                           8
# 3                                           8
# 3                                          11
# 8                                          10

# %%
df = df.groupby(['Profile ID','Date_of_Booking']).size().reset_index(name='Count_frquency')
df.head()
# Out:
#    Profile ID Date_of_Booking  Count_frquency
# 0           1      2018-05-20               1
# 1           1      2018-09-23               1
# 2           3      2018-04-12               1
# 3           3      2018-08-05               1
# 4           8      2018-11-29               1

# %%
df = df.groupby(['Profile ID','Date_of_Booking']).size().rename('Count_frquency').to_frame()

# %%
df.head(20)
# Out:
#                             Count_frquency
# Profile ID Date_of_Booking
# 1          2018-05-20                    1
#            2018-09-23                    1
# 3          2018-04-12                    1
#            2018-08-05                    1
# 8          2018-11-29                    1
#            2018-11-30                    1
# 14         2018-04-30                    1
#            2018-06-07                    1
#            2018-06-21                    1
#            2018-06-24                    1
#            2018-06-29                    1
#            2018-10-10                    1
# 18         2017-12-30                    1
#            2018-11-06                    1
# 22         2018-01-29                    1
#            2018-04-26                    1
#            2018-09-06                    1
# 25         2017-12-30                    1
#            2018-05-14                    1
#            2018-05-24                    1
